# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("2019.csv")
og = data
data
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
info = pd.read_csv("pop_density.csv", decimal=",")
info
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
## analyze population density

# %%
pops = info[["Country", "Pop. Density (per sq. mi.)"]]
pops
# Out:
#              Country  Pop. Density (per sq. mi.)
# 0       Afghanistan                         48.0
# 1           Albania                        124.6
# 2           Algeria                         13.8
# 3    American Samoa                        290.4
# 4           Andorra                        152.1
# ..               ...                         ...
# 222       West Bank                        419.9
# 223  Western Sahara                          1.0
# 224           Yemen                         40.6
# 225          Zambia                         15.3
# 226        Zimbabwe                         31.3
#
# [227 rows x 2 columns]

# %%
pops["pop_density"] = pops["Pop. Density (per sq. mi.)"]
pops = pops.drop("Pop. Density (per sq. mi.)",axis=1)
pops
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              Country  pop_density
# 0       Afghanistan          48.0
# 1           Albania         124.6
# 2           Algeria          13.8
# 3    American Samoa         290.4
# 4           Andorra         152.1
# ..               ...          ...
# 222       West Bank         419.9
# 223  Western Sahara           1.0
# 224           Yemen          40.6
# 225          Zambia          15.3
# 226        Zimbabwe          31.3
#
# [227 rows x 2 columns]

# %%
## Clean and prepare data

# %%
pops["Country"] = pops["Country"].str.rstrip()
pops
# Out:
#             Country  pop_density
# 0       Afghanistan         48.0
# 1           Albania        124.6
# 2           Algeria         13.8
# 3    American Samoa        290.4
# 4           Andorra        152.1
# ..              ...          ...
# 222       West Bank        419.9
# 223  Western Sahara          1.0
# 224           Yemen         40.6
# 225          Zambia         15.3
# 226        Zimbabwe         31.3
#
# [227 rows x 2 columns]

# %%
pops[pops["Country"] == "Afghanistan"]
# Out:
#        Country  pop_density
# 0  Afghanistan         48.0

# %%
data["Country"] = data["Country or region"]
data = data.drop("Country or region",axis=1)
data
# Out:
#      Overall rank  Score  GDP per capita  Social support  \
# 0               1  7.769           1.340           1.587
# 1               2  7.600           1.383           1.573
# 2               3  7.554           1.488           1.582
# 3               4  7.494           1.380           1.624
# 4               5  7.488           1.396           1.522
# ..            ...    ...             ...             ...
# 151           152  3.334           0.359           0.711
# 152           153  3.231           0.476           0.885
# 153           154  3.203           0.350           0.517
# 154           155  3.083           0.026           0.000
# 155           156  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.986                         0.596       0.153
# 1                      0.996                         0.592       0.252
# ...

# %%
s = set(data["Country"])
print("Afghanistan" in s)
# Out:
# True

# %%
ls = []
for country in data["Country"]:
    s = set(pops["Country"])
    if country in s:
        r = pops[pops["Country"] == country]
        ls.append(r["pop_density"].values[0])
    else:
        ls.append('')
ls = np.array(ls)
len(ls)
# Out:
# 156

# %%
data["pop_density"] = ls
data["pop_density"] = data["pop_density"].replace('',np.nan)
data
# Out:
#      Overall rank  Score  GDP per capita  Social support  \
# 0               1  7.769           1.340           1.587
# 1               2  7.600           1.383           1.573
# 2               3  7.554           1.488           1.582
# 3               4  7.494           1.380           1.624
# 4               5  7.488           1.396           1.522
# ..            ...    ...             ...             ...
# 151           152  3.334           0.359           0.711
# 152           153  3.231           0.476           0.885
# 153           154  3.203           0.350           0.517
# 154           155  3.083           0.026           0.000
# 155           156  2.853           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.986                         0.596       0.153
# 1                      0.996                         0.592       0.252
# ...

# %%
data = data.dropna()
data
# Out:
#      Overall rank  Score  GDP per capita  Social support  \
# 0               1  7.769           1.340           1.587
# 1               2  7.600           1.383           1.573
# 2               3  7.554           1.488           1.582
# 3               4  7.494           1.380           1.624
# 4               5  7.488           1.396           1.522
# ..            ...    ...             ...             ...
# 149           150  3.410           0.191           0.560
# 150           151  3.380           0.287           1.163
# 151           152  3.334           0.359           0.711
# 152           153  3.231           0.476           0.885
# 153           154  3.203           0.350           0.517
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.986                         0.596       0.153
# 1                      0.996                         0.592       0.252
# ...

# %%
## linreg on OG data

# %%
og = og.drop(["Country or region", "Country"],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-baa12577356a> in <module>
# ----> 1 og = og.drop(["Country or region", "Country"],axis=1)
#       2 og
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
from sklearn.linear_model import LinearRegression

m = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(og, test_size=.2, random_state=42)

# %%
X_train = train_set.drop(["Overall rank", "Score"], axis=1)
X_test = test_set.drop(["Overall rank", "Score"], axis=1)
X_train
# Out:
#      GDP per capita  Social support  Healthy life expectancy  \
# 56            1.120           1.402                    0.798
# 138           0.275           0.572                    0.410
# 123           0.921           1.000                    0.815
# 128           0.268           0.841                    0.242
# 127           0.385           1.105                    0.308
# ..              ...             ...                      ...
# 71            1.044           1.303                    0.673
# 106           0.947           0.848                    0.874
# 14            1.333           1.538                    0.996
# 92            1.029           1.125                    0.893
# 102           0.673           0.799                    0.508
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 56                          0.498       0.215                      0.060
# 138                         0.293       0.177                      0.085
# ...

# %%
y_train = train_set["Score"]
y_test = test_set["Score"]

# %%
m.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
m.score(X_train, y_train)
# Out:
# 0.8151799559674812

# %%
m.score(X_test, y_test)
# Out:
# 0.6017537913445685

# %%
## now perform linreg on updated dataset with population density factor

train_set, test_set = train_test_split(data, test_size=.2, random_state=42)

X_train = train_set.drop(["Overall rank", "Score", "Country"], axis=1)
X_test = test_set.drop(["Overall rank", "Score", "Country"], axis=1)

y_train = train_set["Score"]
y_test = test_set["Score"]

m.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
data
# Out:
#      Overall rank  Score  GDP per capita  Social support  \
# 0               1  7.769           1.340           1.587
# 1               2  7.600           1.383           1.573
# 2               3  7.554           1.488           1.582
# 3               4  7.494           1.380           1.624
# 4               5  7.488           1.396           1.522
# ..            ...    ...             ...             ...
# 149           150  3.410           0.191           0.560
# 150           151  3.380           0.287           1.163
# 151           152  3.334           0.359           0.711
# 152           153  3.231           0.476           0.885
# 153           154  3.203           0.350           0.517
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                      0.986                         0.596       0.153
# 1                      0.996                         0.592       0.252
# ...

# %%
m.score(X_train, y_train)
# Out:
# 0.8050536674229543

# %%
m.score(X_test, y_test)
# Out:
# 0.7548617089791826

# %%
data["pop_density"] = data["pop_density"].astype(float)
data["pop_density"]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       15.5
# 1      126.5
# 2       14.2
# 3        2.9
# 4      397.1
#        ...
# 149    109.8
# 150     40.6
# 151    328.4
# 152     39.6
# 153     48.0
# Name: pop_density, Length: 142, dtype: float64

# %%
## sanity check

from pandas.plotting import scatter_matrix

attributes = ["Score", "GDP per capita", "Social support",
              "Healthy life expectancy", "pop_density"]
scatter_matrix(data[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a20b90f50>,
# ...
#       dtype=object)

# %%
attributes = ["Score", "pop_density"]
scatter_matrix(data[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a214730d0>,
# ...
#       dtype=object)

# %%
corr_matrix = data.corr()
corr_matrix["Score"].sort_values(ascending=False)
# Out:
# Score                           1.000000
# GDP per capita                  0.785669
# Healthy life expectancy         0.775595
# Social support                  0.773972
# Freedom to make life choices    0.564401
# Perceptions of corruption       0.401152
# Generosity                      0.121192
# pop_density                     0.062252
# Overall rank                   -0.990340
# Name: Score, dtype: float64

# %%
## Conclusion: 
## score with population density: .60
## score without population density: .75
## Pearson correlation between population density and happiness score: .062

## The data shows there is a small positive correlation between a country's population density
## and it's overall happiness

## Note: There might be a non-linear relationship between these factors...
